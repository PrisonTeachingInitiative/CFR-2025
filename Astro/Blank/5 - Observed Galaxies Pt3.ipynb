# %%
# copy and paste the lines needed to read in the large galaxy zoo catalog from the first observed galaxies notebook
import pandas as pd

# read in the data file and save it to a variable named data

data1 = pd.read_csv('../Data/galaxyzoo_research.csv')

# display the data

data1
# Out:
#               OBJID          RA        DEC  REDSHIFT  P_ELLIPTICAL  P_SPIRAL  \
# 0      5.880180e+17  218.580808   8.161055  0.053766      0.530869  0.437261
# 1      5.877300e+17  239.931122   3.644782  0.054367      0.000000  0.961538
# 2      5.877242e+17   10.641342  15.445178  0.079503      0.470876  0.491672
# 3      5.877415e+17  165.379954  28.187846  0.069913      0.532013  0.424623
# 4      5.877300e+17  216.307612  -1.099459  0.055574      0.647059  0.088235
# ...             ...         ...        ...       ...           ...       ...
# 19995  5.877334e+17  231.967240  50.455685  0.073404      0.946228  0.019281
# 19996  5.880177e+17  243.777330   6.092806  0.059610      0.758621  0.000000
# 19997  5.877250e+17  184.644965  -1.598657  0.079722      0.129100  0.562271
# 19998  5.877258e+17  118.714675  45.705057  0.052579      0.837452  0.064308
# 19999  5.880177e+17  173.612528  12.493277  0.079053      0.847757  0.132819
#
#             UMAG       GMAG       RMAG       IMAG       ZMAG   LOG_MASS  \
# 0     -18.684864 -20.204231 -20.955414 -21.298212 -21.558670  10.516412
# 1     -20.101736 -21.384073 -21.838770 -21.980230 -22.158155  10.592430
# 2     -19.834967 -21.217686 -21.850147 -22.147160 -22.348995  10.828524
# 3     -19.435511 -20.811283 -21.509943 -21.847149 -22.106108  10.672685
# 4     -18.376757 -19.623747 -20.199842 -20.470566 -20.681120   9.964785
# ...          ...        ...        ...        ...        ...        ...
# 19995 -19.803755 -21.573761 -22.339725 -22.708660 -22.984587  11.098833
# 19996 -16.315529 -20.404915 -21.282505 -21.124458 -22.213829  11.365675
# 19997 -19.415325 -20.450088 -20.837673 -20.960474 -21.146212  10.002666
# 19998 -19.477306 -21.262995 -22.042334 -22.473787 -22.752541  10.986648
# 19999 -18.893919 -20.679129 -21.359232 -21.659225 -21.890398  10.662863
#
#        R90_ARCSEC  AXIAL_RATIO  LOCAL_DENSITY  NEARCLUSTER_DIST  \
# 0        6.294165     0.368354        -0.1800       -999.000000
# 1       14.513707     0.799851        -0.2080         15.959925
# 2        7.862754     0.879052         0.8070          1.059320
# 3        6.840029     0.930676         0.0285       -999.000000
# 4        3.187091     0.831526         0.1040         11.604042
# ...           ...          ...            ...               ...
# 19995    8.970359     0.721744        -0.5390         12.696922
# 19996   13.147679     0.741964        -0.5400       -999.000000
# 19997    5.776074     0.621813        -0.6670         19.389032
# 19998   11.711008     0.841293         1.4600          0.000000
# 19999    6.333528     0.915966        -0.4550          8.063866
#
#        NEARCLUSTER_MASS
# 0         -9.990000e+02
# 1          5.430000e+12
# 2          3.940000e+14
# 3         -9.990000e+02
# 4          3.740000e+13
# ...                 ...
# 19995      1.450000e+14
# 19996     -9.990000e+02
# 19997      6.630000e+14
# 19998      8.510000e+13
# 19999      1.560000e+14
#
# [20000 rows x 17 columns]

# %% [markdown]
# **Copy and paste your table for the descriptions of the columns**

# %% [markdown]
# ## Galaxy Zoo Types
#
# We only tested a couple of tens of galaxies, but there are billions in the Universe! We can expand our sample by using the full galaxy zoo data that we read in earlier. It still only has a small subsample of galaxies, but 20,000 is much bigger than 20!
#
# Just like before, let's say a galaxy is elliptical if it is classified as elliptical 80% of the time, and that it is a sprial if it is classified as spiral 80% of the time. This means we want the probability to be equal to or greater than 0.8. Pull out the relevant probabilities from the big Galaxy Zoo catalog. Make sure you aren't repeating variable names!

# %%
# grabbing the Galaxy Zoo probability columns
elliptical = data1["P_ELLIPTICAL"]
spiral = data1["P_SPIRAL"]


elliptical_galaxy = elliptical >= 0.8 # create a boolean array
spiral_galaxy = spiral >= 0.8 

elliptical_galaxy
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995     True
# 19996    False
# 19997    False
# 19998     True
# 19999     True
# Name: P_ELLIPTICAL, Length: 20000, dtype: bool

# %%
spiral_galaxy
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: P_SPIRAL, Length: 20000, dtype: bool

# %%
# make Boolean arrays based on the probabilites above

# %%
# the sum of the Boolean arrays tell us how many galaxies passed each test

print('The number of elliptical galaxies is', sum(elliptical_galaxy)) # fill in the sum after the comma
print('The number of spiral galaxies is', sum(spiral_galaxy)) # fill in the sum after the comma
print('The total number of galaxies classifed is', len(elliptical_galaxy + spiral_galaxy ))
# Out:
# The number of elliptical galaxies is 2509
# The number of spiral galaxies is 6881
# The total number of galaxies classifed is 20000

# %% [markdown]
# **How do the results of your data and the full Galaxy Zoo data compare? (Go back to Observed Galaxies Pt2 to see your results)**
#
# **Answer:**

# %% [markdown]
# It is not super fair for us to compare the number of elliptical/spirals in each data group because the sizes are very different. Let's calculate the percent of each type of galaxy in the two data groups. Remember, we can calculate the percent of something by doing: $\rm \frac{number\ of\ specific}{total} \times 100$
#
# Calcualte and compare the 4 percents below.

# %%
# first we need to bring in the data you created in the last notebook. copy and paste the lines of code to read in that data

import pandas as pd
data_class = pd.read_csv('../data/galazyzoo_experiment.csv')

data_class
# Out:
#     Galaxy ID  Total # of classifications  Elliptical  Spiral  Merger  \
# 0           1                          10           0      10       0
# 1           2                          10           6       3       1
# 2           3                          10           2       8       0
# 3           4                          10           8       0       1
# 4           5                          10           5       4       0
# 5           6                          10           0       1       9
# 6           7                          10           0      10       0
# 7           8                          10           7       0       0
# 8           9                          10           8       0       0
# 9          10                          10           0      10       0
# 10         11                           9           5       3       1
# 11         12                          10           0       9       1
# 12         13                          10           2       0       2
# 13         14                          10           0      10       0
# 14         15                          10           3       0       1
# 15         16                          10           0       2       8
# 16         17                          10           9       0       0
# 17         18                          10           7       1       1
# 18         19                          10           4       4       1
# 19         20                          10           5       2       1
# 20         21                          10           0       2       8
# 21         22                          10           0       0      10
#
#     Artifact              SSDS ID  \
# 0          0  1237648720142336185
# 1          0  1237648721215815838
# 2          0  1237648721215946942
# 3          1  1237648721216078045
# 4          1  1237648721216078463
# 5          0  1237648721245503521
# 6          0  1237648722295914556
# 7          3  1237650795146576091
# 8          2  1237650795683381426
# 9          0  1237650796219596962
# 10         0  1237650796220121207
# 11         0  1237650796220514489
# 12         6  1237651538188435488
# 13         0  1237651800697143553
# 14         6  1237652899697983542
# 15         0  1237659896173690952
# 16         1  1237663783667302499
# 17         1  1237663784204107951
# 18         1  1237663785278570672
# 19         2  1237666338115617030
# 20         0  1237667323796127886
# 21         0  1237668365847560462
#
#                                                 Image  GZ Original Elliptical  \
# 0   http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 1   http://skyserver.sdss.org/dr8/en/tools/explore...                       3
# 2   http://skyserver.sdss.org/dr8/en/tools/explore...                       5
# 3   http://skyserver.sdss.org/dr8/en/tools/explore...                      35
# 4   http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 5   http://skyserver.sdss.org/dr8/en/tools/explore...                       1
# 6   http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 7   http://skyserver.sdss.org/dr8/en/tools/explore...                      38
# 8   http://skyserver.sdss.org/dr8/en/tools/explore...                      63
# 9   http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 10  http://skyserver.sdss.org/dr8/en/tools/explore...                      14
# 11  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 12  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 13  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 14  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 15  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 16  http://skyserver.sdss.org/dr8/en/tools/explore...                      21
# 17  http://skyserver.sdss.org/dr8/en/tools/explore...                      25
# 18  http://skyserver.sdss.org/dr8/en/tools/explore...                      33
# 19  http://skyserver.sdss.org/dr8/en/tools/explore...                      15
# 20  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
# 21  http://skyserver.sdss.org/dr8/en/tools/explore...                       0
#
#     GZ Original Spiral  GZ Original Merger  GZ Original Artifact  \
# 0                   37                   0                     0
# 1                   53                   1                     0
# 2                   58                   0                     0
# 3                    0                   0                     0
# 4                   31                   0                     1
# 5                    0                  25                     1
# 6                   23                   0                     0
# 7                    1                   0                     3
# 8                    2                   0                     0
# 9                   26                   0                     0
# 10                  17                   0                     0
# 11                  25                   0                     0
# 12                   0                   0                    31
# 13                  26                   0                     0
# 14                   0                   0                    62
# 15                   2                  22                     0
# 16                   1                   0                     1
# 17                   1                   0                     1
# 18                  22                   0                     1
# 19                   9                   0                     6
# 20                   0                  35                     0
# 21                   0                  27                     0
#
#    Computer Classification
# 0           Not Elliptical
# 1           Not Elliptical
# 2           Not Elliptical
# 3               Elliptical
# 4           Not Elliptical
# 5               Elliptical
# 6           Not Elliptical
# 7      Unable to Determine
# 8      Unable to Determine
# 9           Not Elliptical
# 10     Unable to Determine
# 11          Not Elliptical
# 12          Not Elliptical
# 13          Not Elliptical
# 14          Not Elliptical
# 15          Not Elliptical
# 16     Unable to Determine
# 17              Elliptical
# 18     Unable to Determine
# 19     Unable to Determine
# 20          Not Elliptical
# 21          Not Elliptical

# %%
# copy and paste ALL lines of code after you printed the data table. (You can ignore the print statements at the end.)

# For my data (data1)
elliptical = data1["P_ELLIPTICAL"]
spiral = data1["P_SPIRAL"]

elliptical_galaxy = elliptical >= 0.8
spiral_galaxy = spiral >= 0.8

total_classified = (elliptical_galaxy | spiral_galaxy).sum()
print('The total number of galaxies  classified is', total_classified)

# My data percentages
num_my_elliptical = elliptical_galaxy.sum()
num_my_spiral = spiral_galaxy.sum()
total_my = len(data1)

percent_my_elliptical = (num_my_elliptical / total_my) * 100
percent_my_spiral = (num_my_spiral / total_my) * 100

# For Galaxy Zoo (data_class)
tot_num_classifications = data_class["Total # of classifications"]
elliptical_all = data_class["Elliptical"]
spiral_all = data_class["Spiral"]

prob_elliptical = elliptical_all / tot_num_classifications
prob_spiral = spiral_all / tot_num_classifications

is_elliptical = prob_elliptical >= 0.8
is_spiral = prob_spiral >= 0.8

num_all_elliptical = is_elliptical.sum()
num_all_spiral = is_spiral.sum()
total_all = len(data_class)

percent_all_elliptical = (num_all_elliptical / total_all) * 100
percent_all_spiral = (num_all_spiral / total_all) * 100

# Final output
print('For data1:')
print('The percentage of elliptical galaxies is', percent_my_elliptical, '%')
print('The percentage of spiral galaxies is', percent_my_spiral, '%')
print('  ')
print('For all of the Galaxy Zoo data:')
print('The percentage of elliptical galaxies is', percent_all_elliptical, '%')
print('The percentage of spiral galaxies is', percent_all_spiral, '%')
# Out:
# The total number of galaxies  classified is 9390
# For data1:
# The percentage of elliptical galaxies is 12.545 %
# The percentage of spiral galaxies is 34.405 %
#
# For all of the Galaxy Zoo data:
# The percentage of elliptical galaxies is 13.636363636363635 %
# The percentage of spiral galaxies is 27.27272727272727 %

# %% [markdown]
# **How do the percentages between the two data sets compare?**
#
# **Answer:** Elliptical are close in percentages,, spiral are further apart almost 8%

# %% [markdown]
# ## Galaxy Evolution
#
# Like stars, galaxies form when super massive clouds of gas collapse because of gravity. These super massive clouds form stars overtime, and that creates a galaxy.
#
# Galaxies grow overtime through merging with other galaxies. Similarly to a business merger, this involves at least two galaxies coming together to form a bigger galaxy. Here is a video (https://www.youtube.com/watch?v=SZfOyyGMSGg&ab_channel=VideoFromSpace) showing images of galaxies in the process of merging. Note how they don't have a clear spiral or elliptical shape. This video (https://www.youtube.com/watch?v=lXy3B2K47Qg&ab_channel=VideoFromSpaceVideoFromSpaceVerified) shows computer images matched with real images of galaxies in the process of merging. The merging process takes billions of years, so we cannot watch it happen, which is why we need computers to know what the process looks like. The fact that images from the computer matches real images we see from space gives us confidence that the computer images are accurate!
#
# (I like to think about this as "galactic cannibalism" and that galaxies grow by eating other galaxies.) Galaxies do this A LOT. Our own Milky Way has eaten many small galaxies over time. Below are computer images showing how this could work.
#
# <br>
# <center>
# <div>
# <img src='attachment:image.png' width=600>
# <div>
# <center>
#
# <center>
# Computer images of a galaxy and a smaller galaxy merger across panels 1-6. Note how the final galaxy doesn't look too different from the initial bigger galaxy. The more massive one "wins," and the smaller one is destroyed and eaten by the bigger one.
# <center>
#
#
#
# <br>
#
#
# When two galaxies that have similar masses merge, they form a totally new galaxy that doesn't always look like one of the originals. This is especially true when two spiral galaxies of the same mass merge. They lose their spiral arms and get puffed out, resulting in a galaxy that looks like an ...elliptical galaxy! In fact, this is how we think elliptical galaxies are formed! Check out this vide of two spiral galaxies merge: https://www.youtube.com/watch?v=QcDtJ_-jdMw&ab_channel=HubbleSpaceTelescope
#
# Here is a video (https://www.youtube.com/watch?v=4disyKG7XtU&ab_channel=VideoFromSpace) showing a computer-made video of what will happen in billions of years when the Milky Way and its large neighbor the Andromeda Galaxy collide.

# %% [markdown]
# **What are some observations you notice from the two above videos?**
#
# **Observations:**

# %% [markdown]
# ## Deliverable: Ellipticals vs Spirals Ages
#
# Let's think about the ages of spiral galaxies and elliptical galaxies. It is hard to know the age of a galaxy, so we can focus on general trends.
#
# **Based on the information above, which type of galaxy do you think tend to be older?**
#
# **Your hypothesis:** I know elliptical are supposed to be older.

# %% [markdown]
# How could you test your hypothesis? What data do you have in the galaxy zoo catalog that you could use? **Explain below.** And then experiment!
#
# **Explanation:** Show a comaprison of elliptical and spiral galaxies with color filters RMAG, IMAG, UMAG, GMAG
#
# **In your propsed explanation, what would be the independent variable?**
#
# **In your propsed explanation, what would be the dependent variable?**

# %% [markdown]
# Below add your code to test your hypothesis. Have a clearly labeled plot that you are ready to present to the group. Add statistics to your findings by exploring the mean and standard deviation of your results.

# %%
# add your code below to test your hypothesis

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import matplotlib
matplotlib.rc('font', **{'family':'sans-serif', 'size':16}) 

# Load the data
data1 = pd.read_csv('../Data/galaxyzoo_research.csv')

# Filter by galaxy type probability
ellipticals = data1[data1["P_ELLIPTICAL"] > 0.8]
spirals = data1[data1["P_SPIRAL"] > 0.8]

# Compute color indices
elliptical_galaxy_color = ellipticals["GMAG"] - ellipticals["RMAG"]
spiral_galaxy_color = spirals["GMAG"] - spirals["RMAG"]

# Plot histograms
plt.figure(figsize=(10, 6))
plt.hist(spiral_galaxy_color, bins=25, alpha=0.6, label='Spirals', color='skyblue', edgecolor='black')
plt.hist(elliptical_galaxy_color, bins=30, alpha=0.6, label='Ellipticals', color='red', edgecolor='black')


plt.xlabel('G - R (Color Index)', fontsize=14)
plt.ylabel('Number of Galaxies', fontsize=14)
plt.title('Color Distribution of Spiral and Elliptical Galaxies', fontsize=16)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Statistics
print('The mean color of spiral galaxies is', round(np.mean(spiral_galaxy_color), 2))
print('The mean color of elliptical galaxies is', round(np.mean(elliptical_galaxy_color), 2))
print()
print('The standard deviation of the color of spiral galaxies is', round(np.std(spiral_galaxy_color), 2))
print('The standard deviation of the color of elliptical galaxies is', round(np.std(elliptical_galaxy_color), 2))
# Out:
# The mean color of spiral galaxies is 0.58
# The mean color of elliptical galaxies is 0.75
#
# The standard deviation of the color of spiral galaxies is 0.13
# The standard deviation of the color of elliptical galaxies is 0.08

# %% [markdown]
# **What are your results?**
#
# **Answer:** there are more Elliptical Galaxies than Spiral Galaxies and Elliptical are more on the right side of the G-R Color Index than Spiral
#
# **What conclusion can you make from your results?**
#
# **Answer:** There are more older Elliptical Galaxies than younger Spiral Galaxies
#
# **Is this consistent with waht you learned about galaxy mergers and evolution?**
#
# **Answer:** Yes it is consistent, can this information possibly change now with the technological developments with the JWSP??

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import matplotlib
matplotlib.rc('font', **{'family':'sans-serif', 'size':16}) 

# Load the data
data1 = pd.read_csv('../Data/galaxyzoo_research.csv')

# Filter by galaxy type probability
ellipticals = data1[data1["P_ELLIPTICAL"] > 0.8]
spirals = data1[data1["P_SPIRAL"] > 0.8]

# Compute age proxies: U - I
elliptical_galaxy_age = ellipticals["UMAG"] - ellipticals["IMAG"]
spiral_galaxy_age = spirals["UMAG"] - spirals["IMAG"]

# Plot histograms for age
plt.figure(figsize=(10, 6))
plt.hist(spiral_galaxy_age, bins=25, alpha=0.6, label='Spirals', color='green', edgecolor='black')
plt.hist(elliptical_galaxy_age, bins=30, alpha=0.6, label='Ellipticals', color='orange', edgecolor='black')

plt.xlabel('U - I (Age Indicator)', fontsize=14)
plt.ylabel('Number of Galaxies', fontsize=14)
plt.title('Age Distribution of Spiral and Elliptical Galaxies (U - I)', fontsize=16)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Statistics
print('The mean U - I of spiral galaxies is', round(np.mean(spiral_galaxy_age), 2))
print('The mean U - I of elliptical galaxies is', round(np.mean(elliptical_galaxy_age), 2))
print()
print('The standard deviation of U - I for spiral galaxies is', round(np.std(spiral_galaxy_age), 2))
print('The standard deviation of U - I for elliptical galaxies is', round(np.std(elliptical_galaxy_age), 2))
# Out:
# The mean U - I of spiral galaxies is 2.14
# The mean U - I of elliptical galaxies is 2.83
#
# The standard deviation of U - I for spiral galaxies is 0.53
# The standard deviation of U - I for elliptical galaxies is 0.35

# %% [markdown]
# ## Reflection
#
# We are going to move on from galaxies observations and start talking about galaxy simulations. Before we do so, write down some notes in your lab notebook about what you've learned in this unit. Be sure to include some astronomy and some coding.
